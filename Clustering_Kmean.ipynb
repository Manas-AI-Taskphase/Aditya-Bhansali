# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("weatherAUS.csv")
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
data.shape
# Out:
# (145460, 23)

# %%
data.head()
data=data.drop('Date',axis=1)
data
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145455    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0                W           44.0          W        WNW  ...         71.0
# 1              WNW           44.0        NNW        WSW  ...         44.0
# 2              WSW           46.0          W        WSW  ...         38.0
# 3               NE           24.0         SE          E  ...         45.0
# 4                W           41.0        ENE         NW  ...         82.0
# ...            ...            ...        ...        ...  ...          ...
# 145455           E           31.0         SE        ENE  ...         51.0
# 145456         NNW           22.0         SE          N  ...         56.0
# 145457           N           37.0         SE        WNW  ...         53.0
# 145458          SE           28.0        SSE          N  ...         51.0
# 145459         NaN            NaN        ESE        ESE  ...         62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 22 columns]

# %%
loc_ation=data['Location']
loc_ation
# Out:
# 0         Albury
# 1         Albury
# 2         Albury
# 3         Albury
# 4         Albury
#            ...
# 145455     Uluru
# 145456     Uluru
# 145457     Uluru
# 145458     Uluru
# 145459     Uluru
# Name: Location, Length: 145460, dtype: object

# %%
data=data.drop('Location',axis=1)

# %%
data
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0          13.4     22.9       0.6          NaN       NaN           W
# 1           7.4     25.1       0.0          NaN       NaN         WNW
# 2          12.9     25.7       0.0          NaN       NaN         WSW
# 3           9.2     28.0       0.0          NaN       NaN          NE
# 4          17.5     32.3       1.0          NaN       NaN           W
# ...         ...      ...       ...          ...       ...         ...
# 145455      2.8     23.4       0.0          NaN       NaN           E
# 145456      3.6     25.3       0.0          NaN       NaN         NNW
# 145457      5.4     26.9       0.0          NaN       NaN           N
# 145458      7.8     27.0       0.0          NaN       NaN          SE
# 145459     14.9      NaN       0.0          NaN       NaN         NaN
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0                44.0          W        WNW          20.0  ...         71.0
# 1                44.0        NNW        WSW           4.0  ...         44.0
# 2                46.0          W        WSW          19.0  ...         38.0
# 3                24.0         SE          E          11.0  ...         45.0
# 4                41.0        ENE         NW           7.0  ...         82.0
# ...               ...        ...        ...           ...  ...          ...
# 145455           31.0         SE        ENE          13.0  ...         51.0
# 145456           22.0         SE          N          13.0  ...         56.0
# 145457           37.0         SE        WNW           9.0  ...         53.0
# 145458           28.0        SSE          N          13.0  ...         51.0
# 145459            NaN        ESE        ESE          17.0  ...         62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday RainTomorrow
# 0          21.8         No           No
# 1          24.3         No           No
# 2          23.2         No           No
# 3          26.5         No           No
# 4          29.7         No           No
# ...         ...        ...          ...
# 145455     22.4         No           No
# 145456     24.5         No           No
# 145457     26.1         No           No
# 145458     26.0         No           No
# 145459     20.9         No          NaN
#
# [145460 rows x 21 columns]

# %%
mapping={'E':0,'W':1,'N':2,'S':3,'NE':4,'SE':5,'SW':6,'NW':7,'NNE':8,'ENE':9,'ESE':10,'SSE':11,'SSW':12,'WSW':13,'WNW':14,'NNW':15}
data=data.replace({'WindGustDir':mapping})
data=data.replace({'WindDir9am':mapping})
data=data.replace({'WindDir3pm':mapping})
mapping1={'No':0,'Yes':1}
data=data.replace({'RainToday':mapping1})
data=data.replace({'RainTomorrow':mapping1})
data
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0          13.4     22.9       0.6          NaN       NaN          1.0
# 1           7.4     25.1       0.0          NaN       NaN         14.0
# 2          12.9     25.7       0.0          NaN       NaN         13.0
# 3           9.2     28.0       0.0          NaN       NaN          4.0
# 4          17.5     32.3       1.0          NaN       NaN          1.0
# ...         ...      ...       ...          ...       ...          ...
# 145455      2.8     23.4       0.0          NaN       NaN          0.0
# 145456      3.6     25.3       0.0          NaN       NaN         15.0
# 145457      5.4     26.9       0.0          NaN       NaN          2.0
# 145458      7.8     27.0       0.0          NaN       NaN          5.0
# 145459     14.9      NaN       0.0          NaN       NaN          NaN
#
#         WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0                44.0         1.0        14.0          20.0  ...         71.0
# 1                44.0        15.0        13.0           4.0  ...         44.0
# 2                46.0         1.0        13.0          19.0  ...         38.0
# 3                24.0         5.0         0.0          11.0  ...         45.0
# 4                41.0         9.0         7.0           7.0  ...         82.0
# ...               ...         ...         ...           ...  ...          ...
# 145455           31.0         5.0         9.0          13.0  ...         51.0
# 145456           22.0         5.0         2.0          13.0  ...         56.0
# 145457           37.0         5.0        14.0           9.0  ...         53.0
# 145458           28.0        11.0         2.0          13.0  ...         51.0
# 145459            NaN        10.0        10.0          17.0  ...         62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8        0.0           0.0
# 1          24.3        0.0           0.0
# 2          23.2        0.0           0.0
# 3          26.5        0.0           0.0
# 4          29.7        0.0           0.0
# ...         ...        ...           ...
# 145455     22.4        0.0           0.0
# 145456     24.5        0.0           0.0
# 145457     26.1        0.0           0.0
# 145458     26.0        0.0           0.0
# 145459     20.9        0.0           NaN
#
# [145460 rows x 21 columns]

# %%
data.fillna(0)
data
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0          13.4     22.9       0.6          NaN       NaN          1.0
# 1           7.4     25.1       0.0          NaN       NaN         14.0
# 2          12.9     25.7       0.0          NaN       NaN         13.0
# 3           9.2     28.0       0.0          NaN       NaN          4.0
# 4          17.5     32.3       1.0          NaN       NaN          1.0
# ...         ...      ...       ...          ...       ...          ...
# 145455      2.8     23.4       0.0          NaN       NaN          0.0
# 145456      3.6     25.3       0.0          NaN       NaN         15.0
# 145457      5.4     26.9       0.0          NaN       NaN          2.0
# 145458      7.8     27.0       0.0          NaN       NaN          5.0
# 145459     14.9      NaN       0.0          NaN       NaN          NaN
#
#         WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0                44.0         1.0        14.0          20.0  ...         71.0
# 1                44.0        15.0        13.0           4.0  ...         44.0
# 2                46.0         1.0        13.0          19.0  ...         38.0
# 3                24.0         5.0         0.0          11.0  ...         45.0
# 4                41.0         9.0         7.0           7.0  ...         82.0
# ...               ...         ...         ...           ...  ...          ...
# 145455           31.0         5.0         9.0          13.0  ...         51.0
# 145456           22.0         5.0         2.0          13.0  ...         56.0
# 145457           37.0         5.0        14.0           9.0  ...         53.0
# 145458           28.0        11.0         2.0          13.0  ...         51.0
# 145459            NaN        10.0        10.0          17.0  ...         62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8        0.0           0.0
# 1          24.3        0.0           0.0
# 2          23.2        0.0           0.0
# 3          26.5        0.0           0.0
# 4          29.7        0.0           0.0
# ...         ...        ...           ...
# 145455     22.4        0.0           0.0
# 145456     24.5        0.0           0.0
# 145457     26.1        0.0           0.0
# 145458     26.0        0.0           0.0
# 145459     20.9        0.0           NaN
#
# [145460 rows x 21 columns]

# %%
data=data.interpolate(method ='linear', limit_direction ='forward') 
data
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1      8.00  0.000000     16.9
# 1              25.0       1010.6       1007.8      7.75  0.000000     17.2
# 2              30.0       1007.6       1008.7      7.50  2.000000     21.0
# 3              16.0       1017.6       1012.8      7.25  5.000000     18.1
# 4              33.0       1010.8       1006.0      7.00  8.000000     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3      3.60  4.500000     10.1
# 145456         21.0       1023.5       1019.1      3.40  3.666667     10.9
# 145457         24.0       1021.0       1016.8      3.20  2.833333     12.5
# 145458         24.0       1019.4       1016.5      3.00  2.000000     15.1
# 145459         36.0       1020.2       1017.9      8.00  8.000000     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8        0.0           0.0
# 1          24.3        0.0           0.0
# 2          23.2        0.0           0.0
# 3          26.5        0.0           0.0
# 4          29.7        0.0           0.0
# ...         ...        ...           ...
# 145455     22.4        0.0           0.0
# 145456     24.5        0.0           0.0
# 145457     26.1        0.0           0.0
# 145458     26.0        0.0           0.0
# 145459     20.9        0.0           0.0
#
# [145460 rows x 21 columns]

# %%
scaled_data=preprocessing.scale(data)

# %%
pca=PCA()

# %%
pca.fit(scaled_data)
# Out:
# PCA()

# %%
pca_data=pca.transform(scaled_data)

# %%
per_var=np.round(pca.explained_variance_ratio_*100, decimals=1)
per_var
# Out:
# array([24.2, 15.9,  9.6,  6.3,  5.9,  4.9,  4.6,  4.3,  4.1,  4. ,  3.3,
#         2.5,  2.3,  2.2,  2.1,  1.6,  1.3,  0.5,  0.2,  0.1,  0.1])

# %%
labels=['PC'+str(x) for x in range(1,len(per_var)+1)]
plt.bar(x=range(1,len(per_var)+1),height=per_var,tick_label=labels)
plt.ylabel("Percentage of Explained Variance")
plt.xlabel("Principle component")
plt.title("Scree Plot")
plt.show()

# %%
pca_df=pd.DataFrame(pca_data,index=[*loc_ation],columns=labels)
pca_df
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# Albury  0.676841  0.655707  0.271382 -1.540117 -0.556103 -1.091502  1.984680
# Albury  0.612058 -0.140544 -0.082195 -2.949280  1.779395  0.898221 -0.084507
# Albury  1.384443  0.769812  0.494017 -2.492866 -0.069433  0.255786  2.194419
# Albury  0.427881 -1.262235 -1.712929 -1.300839 -1.802599 -0.676147  0.439891
# Albury  0.814032  1.060203 -2.071273 -1.794844 -1.318832 -0.301173  0.084121
# ...          ...       ...       ...       ...       ...       ...       ...
# Uluru  -0.145633 -2.695850  0.578073  0.087505 -0.559588 -0.663730  0.531104
# Uluru   0.112756 -2.841529  0.106639 -0.250752  0.576685 -0.170991  0.051147
# Uluru   0.795817 -2.377425  0.202986 -0.293252  0.529308 -0.507068  1.048684
# Uluru   1.142231 -2.425133 -0.160682  0.298998  0.329918 -0.669619 -1.144406
# Uluru   0.233221 -0.665321 -0.435929 -0.745066 -0.763553  1.003385 -0.465476
#
#              PC8       PC9      PC10  ...      PC12      PC13      PC14  \
# Albury -1.359893  1.158714 -0.352142  ...  0.804052 -0.620108  1.488154
# Albury -1.796639 -0.294793  0.489546  ...  1.585704 -0.615596  0.933201
# Albury -0.798916 -0.871367  0.046488  ...  0.287342 -0.371485  1.132100
# Albury -1.793241 -0.641243  1.636519  ...  0.154048 -0.526701  0.658303
# Albury -2.016787  0.654256  0.266795  ...  0.658416  0.396894 -0.538801
# ...          ...       ...       ...  ...       ...       ...       ...
# Uluru   0.308721  1.688940  0.999893  ...  0.194208 -0.252884 -0.003659
# Uluru   0.972953 -1.565906  1.594992  ... -0.072193 -0.348108  0.292330
# Uluru   0.341336  1.896593  0.459789  ...  0.473416 -0.285576  0.040857
# Uluru  -0.240208  0.239450  1.276987  ... -0.091889 -0.403124  0.490454
# Uluru   0.711735  1.249809  0.659720  ... -0.356317 -0.362600  0.384984
#
#             PC15      PC16      PC17      PC18      PC19      PC20      PC21
# Albury  2.155291 -0.010689  0.436589 -0.671515 -0.350996 -0.037171  0.094339
# Albury  1.720088 -1.103899 -0.249015  0.350838 -0.114285 -0.040157 -0.070281
# Albury  1.591034 -1.199227  0.130736 -0.010843 -0.362788  0.183019  0.030652
# Albury  0.857144 -0.335817  0.495101  0.131240 -0.065734 -0.131984  0.098307
# Albury  0.288696  0.870874  0.222594 -0.294750  0.435808  0.105707  0.188446
# ...          ...       ...       ...       ...       ...       ...       ...
# Uluru  -0.469661  0.244018  0.258886  0.351212  0.237248  0.103150  0.014595
# Uluru  -0.315074  0.502330  0.760321  0.367334  0.225592  0.120961  0.021031
# Uluru  -0.140917  0.399017 -0.262964  0.416338  0.269720  0.155470 -0.047036
# Uluru   0.089086  0.330585  0.180254  0.245265  0.068874  0.161600 -0.024719
# Uluru  -1.331961  0.182801  0.639514 -0.444007  0.299990  0.273753  0.527933
#
# [145460 rows x 21 columns]

# %%
plt.scatter(pca_df.PC1,pca_df.PC2)
plt.title("PCA graph")
plt.xlabel("PC1-{0}%".format(per_var[0]))
plt.ylabel("PC2-{0}%".format(per_var[1]))
plt.show()
for samples in pca_df.index:
    plt.annotate(sample,(pca_df.PC1.loc[sample],pca_df.PC2.loc[sample]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       5 plt.show()
#       6 for samples in pca_df.index:
# ----> 7     plt.annotate(sample,(pca_df.PC1.loc[sample],pca_df.PC2.loc[sample]))
#       8 plt.show()
#
# NameError: name 'sample' is not defined

# %%
sd=pd.DataFrame(scaled_data)
sd
# Out:
#               0         1         2         3         4         5         6   \
# 0       0.186774 -0.043674 -0.215257 -1.094310 -2.013032 -1.361060  0.297627
# 1      -0.752237  0.265732 -0.285502 -1.094310 -2.013032  1.489613  0.297627
# 2       0.108523  0.350116 -0.285502 -1.094310 -2.013032  1.270330  0.447320
# 3      -0.470534  0.673586 -0.285502 -1.094310 -2.013032 -0.703212 -1.199301
# 4       0.828431  1.278334 -0.168428 -1.094310 -2.013032 -1.361060  0.073088
# ...          ...       ...       ...       ...       ...       ...       ...
# 145455 -1.472146  0.026646 -0.285502  0.652981  0.924913 -1.580342 -0.675376
# 145456 -1.346944  0.293860 -0.285502  0.652981  0.924913  1.708895 -1.348994
# 145457 -1.065241  0.518883 -0.285502  0.652981  0.924913 -1.141777 -0.226298
# 145458 -0.689636  0.532947 -0.285502  0.652981  0.924913 -0.483930 -0.899915
# 145459  0.421527  0.532947 -0.285502  0.652981  0.924913 -0.483930 -0.899915
#
#               7         8         9   ...        11        12        13  \
# 0      -1.358100  1.453057  0.669134  ...  0.109998 -1.429642 -1.374327
# 1       1.734742  1.235120 -1.128275  ... -1.306836 -1.284536 -0.960990
# 2      -1.358100  1.235120  0.556796  ... -1.621689 -1.042694 -1.388580
# 3      -0.474431 -1.598065 -0.341908  ... -1.254361 -1.719853  0.036721
# 4       0.409238 -0.072504 -0.791261  ...  0.687227 -0.897588 -0.932484
# ...          ...       ...       ...  ...       ...       ...       ...
# 145455 -0.474431  0.363371 -0.117232  ... -0.939509 -1.332905  1.034432
# 145456 -0.474431 -1.162190 -0.117232  ... -0.677132 -1.478011  0.877649
# 145457 -0.474431  1.453057 -0.566585  ... -0.834558 -1.332905  0.521324
# 145458  0.851073 -1.162190 -0.117232  ... -0.939509 -1.332905  0.293275
# 145459  0.630156  0.581308  0.332120  ... -0.362280 -0.752482  0.407299
#
#               14        15        16        17        18        19       20
# 0      -1.130233  1.258853 -1.812867 -0.009854  0.014222 -0.548312 -0.54828
# 1      -1.029669  1.164988 -1.812867  0.036313  0.374935 -0.548312 -0.54828
# 2      -0.900372  1.071122 -1.027820  0.621103  0.216221 -0.548312 -0.54828
# 3      -0.311354  0.977257  0.149750  0.174816  0.692362 -0.548312 -0.54828
# 4      -1.288262  0.883391  1.327321  0.128649  1.154075 -0.548312 -0.54828
# ...          ...       ...       ...       ...       ...       ...      ...
# 145455  0.766119 -0.393178 -0.046511 -1.056321  0.100793 -0.548312 -0.54828
# 145456  0.593724 -0.468270 -0.373614 -0.933207  0.403792 -0.548312 -0.54828
# 145457  0.263299 -0.543362 -0.700717 -0.686980  0.634648 -0.548312 -0.54828
# 145458  0.220200 -0.618454 -1.027820 -0.286860  0.620220 -0.548312 -0.54828
# 145459  0.421328  1.258853  1.327321 -0.302249 -0.115635 -0.548312 -0.54828
#
# [145460 rows x 21 columns]

# %%
from sklearn.cluster import KMeans

# %%
def optimize_k(datas,max_k):
    means=[]
    inertias=[]
    for k in range(1,max_k):
        kmeans=KMeans(n_clusters=k)
        kmeans.fit(datas)
        means.append(k)
        inertias.append(kmeans.inertia_)
    fig=plt.subplots(figsize=(10,5))
    plt.plot(means,inertias,'o-')
    plt.xlabel("Number of clusters")
    plt.ylabel("Inertia")
    plt.grid(True)
    plt.show()

# %%
optimize_k(pca_df[["PC1","PC2"]],10)
# Out:
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
kmeans=KMeans(n_clusters=4)
kmeans.fit(pca_df[["PC1","PC2"]])
# Out:
# /home/aditya/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
